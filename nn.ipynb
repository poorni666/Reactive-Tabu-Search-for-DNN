# %%
import numpy
import matplotlib.pyplot as plt
import cv2
import numpy as np

# %%
model = load(

# %%
check = cv2.imread("../input/mnistpredict/3.png")
gray_image = cv2.cvtColor(check,cv2.COLOR_BGR2GRAY)
# print(gray_image)
plt.imshow(gray_image,cmap='Greys')
plt.show()
# gray_image.shape
x = np.expand_dims(gray_image, axis=0)
x = x.reshape((1, -1))
